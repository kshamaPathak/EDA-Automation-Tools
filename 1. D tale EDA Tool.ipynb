# %%
## D-Tale Library EDA Outomation Tool
# !pip install dtale
# Out:
# ...
#      ---------------------------------------- 14.0/14.0 MB 6.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 62.3/62.3 kB 416.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 219.7/219.7 kB 3.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 642.7/642.7 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 65.9/65.9 MB 2.5 MB/s eta 0:00:00
# ...
#      --------------------------------------- 45.9/45.9 kB 95.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 10.2/10.2 MB 7.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 383.4/383.4 kB 2.4 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns
import pandas as pd
import dtale
df=sns.load_dataset('titanic')
#df1=sns.load_dataset('hr_cleaned.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11776\3417123818.py in <module>
#       3 import dtale
#       4 df=sns.load_dataset('titanic')
# ----> 5 df1=sns.load_dataset('hr_cleaned.csv')
#
# E:\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'hr_cleaned.csv' is not one of the example datasets.

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#import dtale
dtale.show(df)
df.drop(columns=['embarked', 'class', 'deck', 'embark_town'], inplace=True)
# Out:
# E:\anaconda3\lib\site-packages\dtale\views.py:756: FutureWarning:
#
# ['embarked', 'class', 'deck', 'embark_town'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
